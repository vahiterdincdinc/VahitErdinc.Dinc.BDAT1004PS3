# %% [markdown]
# # Answer 1

# %%
Answer Step 1-4

# %%
import pandas as pd
users = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')

# %%
users.set_index('user_id')
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
users_grouped=users.groupby("occupation")
mean_occ=users_grouped["age"].mean()
mean_occ
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
Step 5

# %%
Step 6

# %%
users.groupby("occupation").agg({'age':['min','max']})
# Out:
#               age
#               min max
# occupation
# administrator  21  70
# artist         19  48
# doctor         28  64
# educator       23  63
# engineer       22  70
# entertainment  15  50
# executive      22  69
# healthcare     22  62
# homemaker      20  50
# lawyer         21  53
# librarian      23  69
# marketing      24  55
# none           11  55
# other          13  64
# programmer     20  63
# retired        51  73
# salesman       18  66
# scientist      23  55
# student         7  42
# technician     21  55
# writer         18  60

# %%
Step 7

# %%
users.groupby(['occupation', 'gender']).agg({'age':['mean']})
# Out:
#                             age
#                            mean
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
# ...

# %%
Step 8

# %% [markdown]
# # Answer 2

# %%
Step 1

# %%
import pandas as pd

# %%
Step 2-3

# %%
euro12=pd.read_table('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv', sep=',')

# %%
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
Step 4

# %%
euro12["Goals"]
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
Step 5

# %%
print("Total team number is " , len(euro12['Team']))
# Out:
# Total team number is  16

# %%
Step 6

# %%
print("Total columns are " , len(euro12.columns))
# Out:
# Total columns are  35

# %%
Step 7

# %%
discipline=euro12[['Team','Red Cards','Yellow Cards']]
discipline
# Out:
#                    Team  Red Cards  Yellow Cards
# 0               Croatia          0             9
# 1        Czech Republic          0             7
# 2               Denmark          0             4
# 3               England          0             5
# 4                France          0             6
# 5               Germany          0             4
# 6                Greece          1             9
# 7                 Italy          0            16
# 8           Netherlands          0             5
# 9                Poland          1             7
# 10             Portugal          0            12
# 11  Republic of Ireland          1             6
# 12               Russia          0             6
# 13                Spain          0            11
# 14               Sweden          0             7
# 15              Ukraine          0             5

# %%
Step 8

# %%
discipline.sort_values(['Red Cards','Yellow Cards'],ascending=False)
# Out:
#                    Team  Red Cards  Yellow Cards
# 6                Greece          1             9
# 9                Poland          1             7
# 11  Republic of Ireland          1             6
# 7                 Italy          0            16
# 10             Portugal          0            12
# 13                Spain          0            11
# 0               Croatia          0             9
# 1        Czech Republic          0             7
# 14               Sweden          0             7
# 4                France          0             6
# 12               Russia          0             6
# 3               England          0             5
# 8           Netherlands          0             5
# 15              Ukraine          0             5
# 2               Denmark          0             4
# 5               Germany          0             4

# %%
Step 9

# %%
print("Average yellow cards given per team is ",euro12['Yellow Cards'].mean())
# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html
# Reference: https://www.geeksforgeeks.org/python-pandas-dataframe-mean/#:~:text=mean()%20function%20return%20the,the%20observations%20in%20the%20dataframe.
# Out:
# Average yellow cards given per team is  7.4375

# %%
Step 10

# %%
euro12[euro12.Goals>6] 
# The inner "euro12.Goals>6" code creates a series of boolean then the statement prints out when it is true.
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
Step 11

# %%
euro12[euro12.Team.str.startswith('G')] 
# The inner "euro12.Team.str.startswith('G')" code creates a series of boolean then the statement prints out when it is true.
# Reference: https://pandas.pydata.org/docs/reference/api/pandas.Series.str.startswith.html
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
Step 12

# %%
euro12.iloc[:,0:7]
# Reference: https://www.shanelynn.ie/select-data-pandas-iloc-loc-rows-and-columns-dataframe/
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# # Step 13

# %%
euro12.iloc[:,0:-3]
# Reference: https://www.shanelynn.ie/select-data-pandas-iloc-loc-rows-and-columns-dataframe/
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ## Step 14

# %%
euro12.loc[euro12.Team.isin(['England','Italy','Russia']),['Team','Shooting Accuracy']]
#Reference https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isin.html
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Answer 3

# %% [markdown]
# ## Step 1-2

# %%
import random
first=[]
second=[]
third=[]
for i in range(100):
    first.append(random.randrange(1,4))
    second.append(random.randrange(1,3))
    third.append(random.randrange(10000,30000))
firstCol=pd.Series(first,name="FirstCol")
secondCol=pd.Series(second,name="SecondCol")
thirdCol=pd.Series(third,name="ThirdCol")

# %% [markdown]
# ## Step 3

# %%
data=pd.concat([firstCol,secondCol,thirdCol],axis=1)
data
# Out:
#     FirstCol  SecondCol  ThirdCol
# 0          1          1     23176
# 1          2          1     14977
# 2          2          2     15749
# 3          3          2     21866
# 4          3          2     20854
# ..       ...        ...       ...
# 95         2          1     19891
# 96         2          2     15061
# 97         2          1     11675
# 98         1          2     17322
# 99         2          1     11265
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Step 4

# %%
data.rename(columns={'FirstCol':'bedrs', 'SecondCol':'bathrs', 'ThirdCol':'price_sqr_meter'},inplace=True)
data
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       1       1            23176
# 1       2       1            14977
# 2       2       2            15749
# 3       3       2            21866
# 4       3       2            20854
# ..    ...     ...              ...
# 95      2       1            19891
# 96      2       2            15061
# 97      2       1            11675
# 98      1       2            17322
# 99      2       1            11265
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Step 5-6

# %%
allData=pd.DataFrame(data.stack(), columns=['bigcolumns'])
allData
# Using Stack() adds every element in the row with the last columns in a single row.
#In order to fix that we should use reser_index(). I could use reset_index after the stack().reset_index but i wanted to show the step 6
# Out:
#                     bigcolumns
# 0  bedrs                     1
#    bathrs                    1
#    price_sqr_meter       23176
# 1  bedrs                     2
#    bathrs                    1
# ...                        ...
# 98 bathrs                    2
#    price_sqr_meter       17322
# 99 bedrs                     2
#    bathrs                    1
#    price_sqr_meter       11265
#
# [300 rows x 1 columns]

# %% [markdown]
# ## Step 7

# %%
allData.reset_index(drop=True)
# Out:
#      bigcolumns
# 0             1
# 1             2
# 2         28350
# 3             1
# 4             2
# ..          ...
# 295           1
# 296       18815
# 297           1
# 298           1
# 299       24087
#
# [300 rows x 1 columns]

# %% [markdown]
# ## Answer 4

# %%
data=pd.read_table('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data',sep='\s+',parse_dates=[[0,1,2]])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-3bf04c1a7bc2> in <module>
#       1 df=pd.DataFrame(data)
# ----> 2 df["Yr_Mo_Dy"] = pd.where(pd.DatetimeIndex(data["Yr_Mo_Dy"]).year < 2000,data.Date,data.Date - pd.offsets.DateOffset(years=100))
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'where'

# %% [markdown]
# # Answer 5

# %% [markdown]
# ## Step 1-2-3

# %%
chipo=pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv','\t')

# %% [markdown]
# ## Step 4

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ## Step 5

# %%
print("Total rows are " , chipo["order_id"].count())
# Out:
# Total rows are  4622

# %% [markdown]
# ## Step 6

# %%
print("Total columns are " , len(chipo.columns))
# Out:
# Total columns are  5

# %% [markdown]
# ## Step 7

# %%
print("Names of the columns are ", chipo.columns)
# Out:
# Names of the columns are  Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ## Step 8

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ## Step 9

# %%
chipo['item_name'].value_counts().head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %% [markdown]
# ## Step 10

# %%
chipo['item_name'].value_counts().agg(max)
# Out:
# 726

# %% [markdown]
# ## Step 11

# %%
chipo.choice_description.value_counts().head(1)
# Out:
# [Diet Coke]    134
# Name: choice_description, dtype: int64

# %% [markdown]
# ## Step 12

# %%
print("Total orders are ", chipo.quantity.sum())
# Out:
# Total orders are  4972

# %% [markdown]
# ## Step 13

# %%
chipo.item_price=chipo.item_price.str[1:].astype(float)

# %%
chipo["item_price"].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ## Step 14

# %%
chipo.item_price.sum()
# Out:
# 34500.16

# %% [markdown]
# ## Step 15

# %%
print ("Total orders were made in the period is", chipo.order_id.count())
# Out:
# Total orders were made in the period is 4622

# %% [markdown]
# ## Step 16

# %%
print ("Average revenue is", chipo.item_price.mean())
# Out:
# Average revenue is 7.464335785374397

# %% [markdown]
# ## Step 17

# %%
print("This many different items are sold:", chipo['item_name'].value_counts().count())
# Out:
# This many different items are sold: 50

# %% [markdown]
# # Answer 6

# %%
import matplotlib.pyplot as plt
from matplotlib import figure
import sys
import pandas as pd
data=pd.read_csv("us-marriages-divorces-1867-2014.csv")
data
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
plt.figure(figsize=(10,8))
plt.title('Number of Marriges and Divorces', fontdict={'fontsize': 15})
plt.plot(data.Year, data.Marriages_per_1000, 'y.-', label='Marriage')
plt.plot(data.Year, data.Divorces_per_1000, 'r.-', label='Divorce')
plt.xlabel('Through Years')
plt.ylabel('Marriages and Divorces per Capitas')
plt.legend()
plt.show()

# %% [markdown]
# # Answer 7

# %%
data=pd.read_csv("us-marriages-divorces-1867-2014.csv")

# %%
plt.figure(figsize=(10,8))
plt.title('Number of marriges and divorces', fontdict={'fontsize': 15})
plt.plot.bar(data.Year, data.Marriages_per_1000, 'y.-', label='Marriage')
plt.plot.bar(data.Year, data.Divorces_per_1000, 'r.-', label='Divorce')

plt.xlabel('Through Years')
plt.ylabel('Marriages and Divorces per Capitas')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-27c5e1f80e52> in <module>
#       1 plt.figure(figsize=(10,8))
#       2 plt.title('Number of marriges and divorces', fontdict={'fontsize': 15})
# ----> 3 plt.plot.bar(data.Year, data.Marriages_per_1000, 'y.-', label='Marriage')
#       4 plt.plot.bar(data.Year, data.Divorces_per_1000, 'r.-', label='Divorce')
#       5
#
# AttributeError: 'function' object has no attribute 'bar'

# %% [markdown]
# # Answer 8

# %%
import pandas as pd
import seaborn as sns
deadliest_actors = pd.read_csv('actor_kill_counts.csv')
res1 = sns.barplot(x='Count', y='Actor', data=deadliest_actors, order=deadliest_actors.sort_values('Count', ascending=True).Actor)
res1.set_xlabel('Total Kills Number')
res1.set_ylabel('Actor Names')
res1.set_title("Hollywood's Deadliest actors ", size=17)
# Out:
# Text(0.5, 1.0, "Hollywood's Deadliest actors ")

# %% [markdown]
# # Answer 9

# %%
import pandas as pd
emperors=pd.read_csv('roman-emperor-reigns.csv ')
emperors
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 0         Augustus            40.58  Possibly assassinated
# 1         Tiberius            22.50  Possibly assassinated
# 2         Caligula             4.83           Assassinated
# 3         Claudius            13.75  Possibly assassinated
# 4             Nero            13.67                Suicide
# ..             ...              ...                    ...
# 63   Valentinian I            11.00         Natural causes
# 64          Valens            14.00       Killed in battle
# 65         Gratian            16.00           Assassinated
# 66  Valentinian II            17.00  Possibly assassinated
# 67    Theodosius I            16.00         Natural causes
#
# [68 rows x 3 columns]

# %%
plt.legend(emperors["Emperor"], loc='best', bbox_to_anchor=(-0.1, 1.), title="Emperor:")

# %% [markdown]
# # Answer 10

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
data_arc= data.loc[(data['Year']>=2000)&(data['Year']<=2009)]
chart= sns.relplot(x="Total Revenues)", y="PHDs in US", hue="Year", size="Year",
            sizes=(40, 400), alpha=.4, palette="muted",
            height=5, data=data)
plt.title("PHDs and Total Revenue Relationship", fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-53eb17a1aa60> in <module>
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 data=pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
#       5 data_arc= data.loc[(data['Year']>=2000)&(data['Year']<=2009)]
#       6 chart= sns.relplot(x="Total Revenues)", y="PHDs in US", hue="Year", size="Year",
#
# ...
